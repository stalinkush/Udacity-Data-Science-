# %% [markdown]
# ### Central Limit Theorem - Part II
#
# Work through the questions and use the created variables to answer the questions that follow below the notebook.
#
# Run the below cell to get started.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
np.random.seed(42)
sns.set()

pop_data = np.random.gamma(1,100,3000)
plt.hist(pop_data);

# %% [markdown]
# `1.` In order to create the sampling distribution for the average of 100 draws of this distribution, follow these steps:
#
# `a.` Use numpy's **random.choice** to simulate 100 draws from the `pop_data` array.   <br><br>
# `b.` Compute the mean of these 100 draws. <br><br>
# `c.` Write a loop to simulate this process 10,000 times, and store each mean into an array called **means_size_100**.<br><br>
# `d.` Plot a histogram of your sample means.<br><br>
# `e.` Use **means_size_100** and **pop_data** to answer the quiz questions below.

# %%
draw = np.random.choice(pop_data, 100)
print('Mean of draw: {}'.format(draw.mean()))
# Out:
# Mean of draw: 115.89760480820178

# %%
means_size_100 = []
for i in range(10000):
    sample = np.random.choice(pop_data, 100)
    sample = sample.mean()
    means_size_100.append(sample)

# %%
plt.figure(figsize=(10,8))
plt.hist(means_size_100)
plt.title('Histogram of Sampling Distribution\n with Sample Size of 100', fontsize=15);

# %%
print(' Population Mean: {} \n Sample Mean: {}'.format(pop_data.mean(), np.mean(means_size_100)))
# Out:
#  Population Mean: 100.35978700795846
#  Sample Mean: 100.45707456518824

# %%
print(' Population Variance: {} \n Sample Variance: {}'.format(np.var(pop_data), np.var(means_size_100)))
# Out:
#  Population Variance: 9955.76939306549
#  Sample Variance: 99.44037691417994
