# %% [markdown]
# ### Central Limit Theorem
#
# Work through the questions and use the created variables to answer the questions that follow below the notebook.
#
# Run the below cell to get started.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
np.random.seed(42)
sns.set() 

pop_data = np.random.gamma(1,100,3000)
plt.hist(pop_data);

# %% [markdown]
# `1.` In order to create the sampling distribution for the average of 3 draws of this distribution, follow these steps:
#
# `a.` Use numpy's **random.choice** to simulate 3 draws from the `pop_data` array.   <br><br>
# `b.` Compute the mean of these 3 draws. <br><br>
# `c.` Write a loop to simulate this process 10,000 times, and store each mean into an array called **means_size_3**.<br><br>
# `d.` Plot a histogram of your sample means.<br><br>
# `e.` Use **means_size_3** and **pop_data** to answer the quiz questions below.

# %%
draw = np.random.choice(pop_data, 3)
print('Mean of draw: {}'.format(draw.mean()))
# Out:
# Mean of draw: 34.86585877838206

# %%
means_size_3 = []
for i in range(10000):
    sample = np.random.choice(pop_data, 3)
    sample = sample.mean()
    means_size_3.append(sample)

# %%
plt.figure(figsize=(10,8))
plt.hist(means_size_3)
plt.title('Histogram of Sampling Distribution\n with Sample size of 3', fontsize='15')
plt.axvline(np.mean(means_size_3), color='k', linestyle='--', label='Mean = {:.4f}'.format(np.mean(means_size_3)))
plt.legend(frameon=True, fontsize=15, facecolor='b', framealpha=0.4);

# %%
print(' Population Mean: {} \n Sample Mean: {}'.format(pop_data.mean(), np.mean(means_size_3)))
# Out:
#  Population Mean: 100.35978700795846
#  Sample Mean: 100.87276259567305

# %%
print(' Population Std: {} \n Sample Std: {}'.format(pop_data.std(), np.std(means_size_3)))
# Out:
#  Population Std: 99.77860187968906
#  Sample Std: 57.72348461511113
